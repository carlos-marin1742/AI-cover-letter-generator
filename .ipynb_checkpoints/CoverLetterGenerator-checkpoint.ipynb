# %% [markdown]
# ### Automating Cover Letters using Langhchain and Python
# This AI function is going to generate cover letter based on your resume provided and job description.

# %% [markdown]
# #### Importing important modules

# %%
from google import genai
from dotenv import load_dotenv
import os
import json
import pandas as pd
from PyPDF2 import PdfReader

# %% [markdown]
# #### Loading our API key fromn the environment variables to connect with Google Gemini API

# %%
#Loading our API key from the environment variables to connect with Google Gemini API
load_dotenv()


#Check if the key was actually loaded (for debugging)
api_key = os.getenv("GEMINI_API_KEY")
if not api_key:
    print("ERROR: GEMINI_API_KEY not found. Check your .env file!")
else:
    print("SUCCESSS!! API Key loaded successfully.")
# Out:
# SUCCESSS!! API Key loaded successfully.

# %% [markdown]
# #### Creating a reusable template that tells the program how to generate a customized cover letter using a person’s resume and a specific job description.

# %%
#importing important module
from langchain_core.prompts import PromptTemplate

#creating the reusable Template
template = PromptTemplate(
input_variables=["resume", "job_description"],
template = """
Using the following resume and job description, write a professional, personalized, and compelling cover letter tailored for this job.
Resume:
{resume}
Job Description:
{job_description}
The Cover letter should:
- Start wiuth a strong introduction
- Highlight key skills and experiences
- Explain why the candidate is a great fit
- End with a polite call-to-action
Return only the cover letter text
""")

# %% [markdown]
# #### Initializing the large language model(LLM) interface using Google’s Gemini API through LangChain.

# %%
# initializing the large language model interface using Google’s Gemini API through LangChain.
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model = "gemini-2.5-flash-lite")

# %% [markdown]
# #### Data pipeline that formats input, generates text with the language model, and outputs it as a plain string.

# %%
#creating chain data pipeline
from langchain_core.output_parsers import StrOutputParser

chain = template | llm | StrOutputParser()

# %%
#extracting data from resume saved in the project directory
def extract_text_from_pdf(pdf_path):
    reader = PdfReader(pdf_path)
    text= ""
    for page in reader.pages:
        text += page.extract_text()
    return text

resume_text = extract_text_from_pdf("resume.pdf")
print("Resume text extracted successfully")
print(resume_text[:500])
# Out:
# Resume text extracted successfully
# Carlos
#
# Marin
#
# Houston,
#
# TX
#
# |
#
# 713-791-3494
#
# |
#
# carlosmarinjr1@gmail.com
#
# |
#
# Portfolio
#
# |
#
# GitHub
#
# |
#
# LinkedIn
#
#
#
#
#
#
#
#
#
#
# AI
#
# Developer
#
# /
#
# Machine
#
# Learning
#
# Engineer
#
# AI
#
# Developer
#
# with
#
# a
#
# solid
#
# foundation
#
# in
#
# machine
#
# learning
#
# and
#
# deep
#
# learning
#
# principles,
#
# certiﬁed
#
# by
#
# the
#
# IBM
#
# AI
#
# Engineering
#
# Professional
#
# Certiﬁcate.
#
# Proﬁcient
#
# in
#
# end-to-end
#
# model
#
# development
#
# using
#
# Python,
#
# Scikit-learn,
#
# TensorFlow,
#
# and
#
# Keras.

# %%
#defining a sample job description text
job_description_text = """ 
We are seeking an AI developer who can asssist in the development and maintenance of AI-driven applications, 
collaborating with engineers and data scientists to translate business requirements into working ML solutions.
"""

# %%
cover_letter = chain.invoke({
    "resume": resume_text,
    "job_description":job_description_text

})

# %%
print(cover_letter)
# Out:
# [Your Name]
# [Your Address]
# [Your Phone Number]
# [Your Email Address]
# [Your Portfolio/LinkedIn URL (Optional)]
#
# [Date]
#
# [Hiring Manager Name (if known), or "Hiring Team"]
# [Hiring Manager Title]
# [Company Name]
# [Company Address]
#
# Dear [Mr./Ms./Mx. Last Name of Hiring Manager, or "Hiring Team"],
#
# I am writing with genuine enthusiasm to express my keen interest in the AI Developer position at [Company Name], as advertised on [Platform where you saw the advertisement]. With my proven track record in end-to-end AI model development, coupled with a strong foundation in machine learning principles and a passion for creating innovative, data-driven solutions, I am confident that my skills and experience align perfectly with your team's needs.
#
# My journey as an AI Developer, solidified by the IBM AI Engineering Professional Certificate, has equipped me with a comprehensive understanding of the AI lifecycle. I am highly proficient in Python and its key libraries such as Pandas, NumPy, and Scikit-learn, and possess extensive experience with deep learning frameworks like TensorFlow and Keras. This technical acumen is directly transferable to your objective of developing and maintaining AI-driven applications. I am particularly drawn to your emphasis on collaborating with engineers and data scientists to translate business requirements into tangible ML solutions, a process I have actively engaged in during my technical projects.
#
# In my project "Emotion Detection Flask App," I successfully engineered a REST API leveraging IBM Watson's NLP capabilities to classify emotions in text, directly addressing user experience and providing instant feedback. This project showcases my ability to build functional AI applications and my understanding of how to integrate pre-trained models to optimize development time and resources. Furthermore, my "Optimizing Food Cost and Profitability" project highlights my ability to extract, standardize, and analyze complex data, then translate those insights into actionable strategies for improved margins, demonstrating a clear business-focused approach to AI development. My experience as a Clinical Research Coordinator at Houston Methodist Hospital has also honed my skills in data integrity, extracting and analyzing EMR datasets, and partnering with cross-functional teams to improve processes – all transferable skills essential for a collaborative AI development environment.
#
# I am eager to contribute my expertise in areas such as supervised and unsupervised learning, NLP, and deep learning to [Company Name]'s innovative projects. My goal is to leverage my robust AI development skills to create impactful, data-driven products, and I believe [Company Name]'s forward-thinking approach makes it the ideal environment for me to achieve this.
#
# Thank you for considering my application. I have attached my resume for your review and welcome the opportunity to discuss how my qualifications and passion for AI development can benefit your team. I look forward to hearing from you soon.
#
# Sincerely,
# Carlos Marin
